# %%
import ipywidgets as widgets

# %% [markdown]
# ## The Legal Widgets

# %%
# Legal issues: fail

t='No adequate engagement with this criterion.'

legal_fail_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

legal_fail_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

legal_fail_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

legal_fail_row=widgets.HBox([widgets.Text(value='Fail',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             legal_fail_checkbox,
                             legal_fail_slider,
                             legal_fail_value_box])

# Legal issues: poor

t='States origin of datasets used, but does not clearly justify \
why their use in this investigation is permissible. Identifies \
any person-identifying data in the dataset.'

legal_poor_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

legal_poor_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

legal_poor_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

legal_poor_row=widgets.HBox([widgets.Text(value='Poor',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=True,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             legal_poor_checkbox,
                             legal_poor_slider,
                             legal_poor_value_box])


# Legal issues: Sufficient

t='As above, plus: \n \
Provides evidence that the dataset can be distributed by the \
dataset provider. Clearly identifies licences and allowed uses \
of data, ensures that all data used in this report is allowed.'

legal_sufficient_checkbox=widgets.Checkbox(value=False,
                                           # description='Check me',
                                           disabled=False,
                                           layout=widgets.Layout(width='5%'))

legal_sufficient_slider=widgets.IntSlider(value=0,
                                          min=-1,
                                          max=1,
                                          step=1,
                                          disabled=True,
                                          continuous_update=False,
                                          orientation='horizontal',
                                          readout=False,
                                          readout_format='d',
                                          layout=widgets.Layout(width='10%'))

legal_sufficient_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

legal_sufficient_row=widgets.HBox([widgets.Text(value='Sufficient',
                                          layout=widgets.Layout(width='10%')),
                                   widgets.Textarea(value=t,
                                                    disabled=False,
                                                    layout=widgets.Layout(width='65%',
                                                                          height='100px')),
                                   legal_sufficient_checkbox,
                                   legal_sufficient_slider,
                                   legal_sufficient_value_box])


# Legal issues: Good

t='As above, plus: \n \
Demonstrates understanding of any impact the data use will have \
on people or organisations, even if wanted and legal.'


legal_good_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

legal_good_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

legal_good_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

legal_good_row=widgets.HBox([widgets.Text(value='Good',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             legal_good_checkbox,
                             legal_good_slider,
                             legal_good_value_box])

# Legal issues: Excellent

t='As above, plus: \n \
Explains how the combination of multiple sets of data \
could have an impact larger than any one set, and shows \
the significance of that impact.'


legal_excellent_checkbox=widgets.Checkbox(value=False,
                                          # description='Check me',
                                          disabled=False,
                                          layout=widgets.Layout(width='5%'))

legal_excellent_slider=widgets.IntSlider(value=0,
                                         min=-1,
                                         max=0,
                                         step=1,
                                         disabled=True,
                                         continuous_update=False,
                                         orientation='horizontal',
                                         readout=False,
                                         readout_format='d',
                                         layout=widgets.Layout(width='10%'))

legal_excellent_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

legal_excellent_row=widgets.HBox([widgets.Text(value='Excellent',
                                          layout=widgets.Layout(width='10%')),
                                  widgets.Textarea(value=t,
                                                   disabled=False,
                                                   layout=widgets.Layout(width='65%',
                                                                         height='100px')),
                                  legal_excellent_checkbox,
                                  legal_excellent_slider,
                                  legal_excellent_value_box])

legal_comments_box=widgets.Textarea(value='',
                                    placeholder="Comments on legal issues ",
                                    disabled=False,
                                    layout=widgets.Layout(width='70%'))

legal_score_box=widgets.IntText(value=0,
                                disabled=True,
                                layout=widgets.Layout(width='100%'))

legal_fail_value_box.children=[legal_score_box]

# %%
# Behaviour for Fail checkbox

def legal_fail_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            legal_fail_slider.value=0
            legal_fail_slider.disabled=False
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=2
            legal_fail_value_box.children=[legal_score_box]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

            
        else:
            legal_poor_checkbox.value=False
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True

            legal_score_box.value=0
            legal_fail_value_box.children=[legal_score_box]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

legal_fail_checkbox.observe(legal_fail_checkbox_f)

# %%
# Behaviour for Fail slider

def legal_fail_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            legal_score_box.value=1
        elif change['new']==0:
            legal_score_box.value=2
        else:
            legal_score_box.value=3

legal_fail_slider.observe(legal_fail_slider_f)

# %%
# Behaviour for Poor checkbox

def legal_poor_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            legal_fail_checkbox.value=True
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=False
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=4
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[legal_score_box]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

            
        else:
            legal_sufficient_checkbox.value=False
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=False
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=2
            legal_fail_value_box.children=[legal_score_box]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

legal_poor_checkbox.observe(legal_poor_checkbox_f)

# %%
# Behaviour for Poor slider

def legal_poor_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            legal_score_box.value=3
        elif change['new']==0:
            legal_score_box.value=4
        else:
            legal_score_box.value=5

legal_poor_slider.observe(legal_poor_slider_f)

# %%
# Behaviour for Sufficient checkbox

def legal_sufficient_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            legal_poor_checkbox.value=True
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=False
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=6
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[legal_score_box]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]
            
        else:
            legal_good_checkbox.value=False
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=False
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=4
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[legal_score_box]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

legal_sufficient_checkbox.observe(legal_sufficient_checkbox_f)

# %%
# Behaviour for Sufficient slider

def legal_sufficient_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            legal_score_box.value=5
        elif change['new']==0:
            legal_score_box.value=6
        else:
            legal_score_box.value=7

legal_sufficient_slider.observe(legal_sufficient_slider_f)

# %%
# Behaviour for Good checkbox

def legal_good_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            legal_sufficient_checkbox.value=True
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=False
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=8
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[legal_score_box]
            legal_excellent_value_box.children=[]

        else:
            legal_excellent_checkbox.value=False
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=False
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=6
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[legal_score_box]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[]

legal_good_checkbox.observe(legal_good_checkbox_f)

# %%
# Behaviour for Good slider

def legal_good_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            legal_score_box.value=7
        elif change['new']==0:
            legal_score_box.value=8
        else:
            legal_score_box.value=9

legal_good_slider.observe(legal_good_slider_f)

# %%
# Behaviour for Good checkbox

def legal_excellent_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            legal_good_checkbox.value=True
            
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=True
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=False
            
            legal_score_box.value=10
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[legal_score_box]
            
        else:
            legal_fail_slider.value=0
            legal_fail_slider.disabled=True
            
            legal_poor_slider.value=0
            legal_poor_slider.disabled=True
            
            legal_sufficient_slider.value=0
            legal_sufficient_slider.disabled=True
            
            legal_good_slider.value=0
            legal_good_slider.disabled=False
            
            legal_excellent_slider.value=0
            legal_excellent_slider.disabled=True
            
            legal_score_box.value=8
            legal_fail_value_box.children=[]
            legal_poor_value_box.children=[]
            legal_sufficient_value_box.children=[]
            legal_good_value_box.children=[]
            legal_excellent_value_box.children=[legal_score_box]

legal_excellent_checkbox.observe(legal_excellent_checkbox_f)

# %%
# Behaviour for Excellent slider

def legal_excellent_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            legal_score_box.value=9
        else:
            legal_score_box.value=10

legal_excellent_slider.observe(legal_excellent_slider_f)

# %%
# Now we need to put all the legal stuff into a single widget.

legal_widget=widgets.VBox([widgets.HTML(value='<h2>Legal Issues</h2>'),
                           legal_fail_row,
                           legal_poor_row,
                           legal_sufficient_row,
                           legal_good_row,
                           legal_excellent_row,
                           legal_comments_box])

# display(legal_widget)

# %% [markdown]
# ## The Data Widgets

# %%
# data issues: fail

t='No adequate engagement with this criterion.'

data_fail_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

data_fail_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

data_fail_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

data_fail_row=widgets.HBox([widgets.Text(value='Fail',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             data_fail_checkbox,
                             data_fail_slider,
                             data_fail_value_box])

# data issues: poor

t='States the two questions addressed in the report, justifies \
why the questions are of interest to the report’s audience, and \
shows that the analysis addresses the question.'

data_poor_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

data_poor_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

data_poor_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

data_poor_row=widgets.HBox([widgets.Text(value='Poor',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=True,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             data_poor_checkbox,
                             data_poor_slider,
                             data_poor_value_box])


# data issues: Sufficient

t='As above, plus: \n Links questions addressed in this report to \
other  questions and issues in the same domain. Gives some limitations \
of the analysis performed.'

data_sufficient_checkbox=widgets.Checkbox(value=False,
                                           # description='Check me',
                                           disabled=False,
                                           layout=widgets.Layout(width='5%'))

data_sufficient_slider=widgets.IntSlider(value=0,
                                          min=-1,
                                          max=1,
                                          step=1,
                                          disabled=True,
                                          continuous_update=False,
                                          orientation='horizontal',
                                          readout=False,
                                          readout_format='d',
                                          layout=widgets.Layout(width='10%'))

data_sufficient_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

data_sufficient_row=widgets.HBox([widgets.Text(value='Sufficient',
                                          layout=widgets.Layout(width='10%')),
                                   widgets.Textarea(value=t,
                                                    disabled=False,
                                                    layout=widgets.Layout(width='65%',
                                                                          height='100px')),
                                   data_sufficient_checkbox,
                                   data_sufficient_slider,
                                   data_sufficient_value_box])


# data issues: Good

t='As above, plus: \n Quantifies strength of conclusions \
and interprets this quantification. Clearly sets out limits of \
analysis performed, stating whether they are limits of the data \
or the analysis method.'


data_good_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

data_good_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

data_good_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

data_good_row=widgets.HBox([widgets.Text(value='Good',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             data_good_checkbox,
                             data_good_slider,
                             data_good_value_box])

# data issues: Excellent

t='As above, plus: \n Gives clear evidence why the \
questions being addressed are important, and outlines \
how the answers might be used to promote change.'


data_excellent_checkbox=widgets.Checkbox(value=False,
                                          # description='Check me',
                                          disabled=False,
                                          layout=widgets.Layout(width='5%'))

data_excellent_slider=widgets.IntSlider(value=0,
                                         min=-1,
                                         max=0,
                                         step=1,
                                         disabled=True,
                                         continuous_update=False,
                                         orientation='horizontal',
                                         readout=False,
                                         readout_format='d',
                                         layout=widgets.Layout(width='10%'))

data_excellent_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

data_excellent_row=widgets.HBox([widgets.Text(value='Excellent',
                                          layout=widgets.Layout(width='10%')),
                                  widgets.Textarea(value=t,
                                                   disabled=False,
                                                   layout=widgets.Layout(width='65%',
                                                                         height='100px')),
                                  data_excellent_checkbox,
                                  data_excellent_slider,
                                  data_excellent_value_box])

data_comments_box=widgets.Textarea(value='',
                                    placeholder="Comments on data issues ",
                                    disabled=False,
                                    layout=widgets.Layout(width='70%'))

data_score_box=widgets.IntText(value=0,
                                disabled=True,
                                layout=widgets.Layout(width='100%'))

data_fail_value_box.children=[data_score_box]

# Behaviour for Fail checkbox

def data_fail_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            data_fail_slider.value=0
            data_fail_slider.disabled=False
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=2
            data_fail_value_box.children=[data_score_box]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

            
        else:
            data_poor_checkbox.value=False
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True

            data_score_box.value=0
            data_fail_value_box.children=[data_score_box]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

data_fail_checkbox.observe(data_fail_checkbox_f)

# Behaviour for Fail slider

def data_fail_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            data_score_box.value=1
        elif change['new']==0:
            data_score_box.value=2
        else:
            data_score_box.value=3

data_fail_slider.observe(data_fail_slider_f)


# Behaviour for Poor checkbox

def data_poor_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            data_fail_checkbox.value=True
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=False
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=4
            data_fail_value_box.children=[]
            data_poor_value_box.children=[data_score_box]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

            
        else:
            data_sufficient_checkbox.value=False
            
            data_fail_slider.value=0
            data_fail_slider.disabled=False
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=2
            data_fail_value_box.children=[data_score_box]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

data_poor_checkbox.observe(data_poor_checkbox_f)

# Behaviour for Poor slider

def data_poor_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            data_score_box.value=3
        elif change['new']==0:
            data_score_box.value=4
        else:
            data_score_box.value=5

data_poor_slider.observe(data_poor_slider_f)

# Behaviour for Sufficient checkbox

def data_sufficient_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            data_poor_checkbox.value=True
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=False
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=6
            data_fail_value_box.children=[]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[data_score_box]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]
            
        else:
            data_good_checkbox.value=False
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=False
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=4
            data_fail_value_box.children=[]
            data_poor_value_box.children=[data_score_box]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

data_sufficient_checkbox.observe(data_sufficient_checkbox_f)


# Behaviour for Sufficient slider

def data_sufficient_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            data_score_box.value=5
        elif change['new']==0:
            data_score_box.value=6
        else:
            data_score_box.value=7

data_sufficient_slider.observe(data_sufficient_slider_f)

# Behaviour for Good checkbox

def data_good_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            data_sufficient_checkbox.value=True
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=False
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=8
            data_fail_value_box.children=[]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[data_score_box]
            data_excellent_value_box.children=[]

        else:
            data_excellent_checkbox.value=False
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=False
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=6
            data_fail_value_box.children=[]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[data_score_box]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[]

data_good_checkbox.observe(data_good_checkbox_f)

# Behaviour for Good slider

def data_good_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            data_score_box.value=7
        elif change['new']==0:
            data_score_box.value=8
        else:
            data_score_box.value=9

data_good_slider.observe(data_good_slider_f)

# Behaviour for Good checkbox

def data_excellent_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            data_good_checkbox.value=True
            
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=True
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=False
            
            data_score_box.value=10
            data_fail_value_box.children=[]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[data_score_box]
            
        else:
            data_fail_slider.value=0
            data_fail_slider.disabled=True
            
            data_poor_slider.value=0
            data_poor_slider.disabled=True
            
            data_sufficient_slider.value=0
            data_sufficient_slider.disabled=True
            
            data_good_slider.value=0
            data_good_slider.disabled=False
            
            data_excellent_slider.value=0
            data_excellent_slider.disabled=True
            
            data_score_box.value=8
            data_fail_value_box.children=[]
            data_poor_value_box.children=[]
            data_sufficient_value_box.children=[]
            data_good_value_box.children=[]
            data_excellent_value_box.children=[data_score_box]

data_excellent_checkbox.observe(data_excellent_checkbox_f)

# Behaviour for Excellent slider

def data_excellent_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            data_score_box.value=9
        else:
            data_score_box.value=10

data_excellent_slider.observe(data_excellent_slider_f)

# Now we need to put all the data stuff into a single widget.

data_widget=widgets.VBox([widgets.HTML(value='<h2>Use data to answer a practical question</h2>'),
                           data_fail_row,
                           data_poor_row,
                           data_sufficient_row,
                           data_good_row,
                           data_excellent_row,
                           data_comments_box])

# display(data_widget)

# %% [markdown]
# ## The Report Widgets

# %%
# report issues: fail

t='No adequate engagement with this criterion.'

report_fail_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

report_fail_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

report_fail_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

report_fail_row=widgets.HBox([widgets.Text(value='Fail',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             report_fail_checkbox,
                             report_fail_slider,
                             report_fail_value_box])

# report issues: poor

t='Report is clearly written and structured, including mostly correct \
spelling, punctuation and grammar. Deviations from the TM351 report \
structure are appropriate for the report. Report is comprehensible to \
someone who is not a data analysis specialist. States some assumptions \
underlying the analysis, relevant results, and some conclusions that \
can be drawn from them. States data analysis methods used. Gives an \
outline explanation of how the analysis was performed. Report summary \
states questions addressed, datasets used, methods used, and \
conclusions drawn.'

report_poor_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

report_poor_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

report_poor_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

report_poor_row=widgets.HBox([widgets.Text(value='Poor',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=True,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             report_poor_checkbox,
                             report_poor_slider,
                             report_poor_value_box])


# report issues: Sufficient

t='As above, plus: \n Target audience is clearly stated in the \
report, and the report is written at an appropriate level for \
that audience. Spelling, punctuation and grammar are clear \
throughout. States most assumptions underlying the analysis. \
Shows how conclusions arise from analysis results.'

report_sufficient_checkbox=widgets.Checkbox(value=False,
                                           # description='Check me',
                                           disabled=False,
                                           layout=widgets.Layout(width='5%'))

report_sufficient_slider=widgets.IntSlider(value=0,
                                          min=-1,
                                          max=1,
                                          step=1,
                                          disabled=True,
                                          continuous_update=False,
                                          orientation='horizontal',
                                          readout=False,
                                          readout_format='d',
                                          layout=widgets.Layout(width='10%'))

report_sufficient_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

report_sufficient_row=widgets.HBox([widgets.Text(value='Sufficient',
                                          layout=widgets.Layout(width='10%')),
                                   widgets.Textarea(value=t,
                                                    disabled=False,
                                                    layout=widgets.Layout(width='65%',
                                                                          height='100px')),
                                   report_sufficient_checkbox,
                                   report_sufficient_slider,
                                   report_sufficient_value_box])


# report issues: Good

t='As above, plus: \n Clearly states all assumptions \
underlying the data analysis. Clearly draws links from \
data to analysis results to conclusions to relevance to \
originating questions. Explains data analysis methods \
sufficiently so that a non-expert reader has some insight \
into their applicability and limitations in this study.'


report_good_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

report_good_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

report_good_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

report_good_row=widgets.HBox([widgets.Text(value='Good',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             report_good_checkbox,
                             report_good_slider,
                             report_good_value_box])

# report issues: Excellent

t='As above, plus: \n \
Includes assumptions that underlie the collection of the \
original datasets, and describes how those could impact \
this analysis. Clearly justifies uses of data analysis \
methods and explains how they generate the results given.'


report_excellent_checkbox=widgets.Checkbox(value=False,
                                          # description='Check me',
                                          disabled=False,
                                          layout=widgets.Layout(width='5%'))

report_excellent_slider=widgets.IntSlider(value=0,
                                         min=-1,
                                         max=0,
                                         step=1,
                                         disabled=True,
                                         continuous_update=False,
                                         orientation='horizontal',
                                         readout=False,
                                         readout_format='d',
                                         layout=widgets.Layout(width='10%'))

report_excellent_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

report_excellent_row=widgets.HBox([widgets.Text(value='Excellent',
                                          layout=widgets.Layout(width='10%')),
                                  widgets.Textarea(value=t,
                                                   disabled=False,
                                                   layout=widgets.Layout(width='65%',
                                                                         height='100px')),
                                  report_excellent_checkbox,
                                  report_excellent_slider,
                                  report_excellent_value_box])

report_comments_box=widgets.Textarea(value='',
                                    placeholder="Comments on report issues ",
                                    disabled=False,
                                    layout=widgets.Layout(width='70%'))

report_score_box=widgets.IntText(value=0,
                                disabled=True,
                                layout=widgets.Layout(width='100%'))

report_fail_value_box.children=[report_score_box]

# Behaviour for Fail checkbox

def report_fail_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            report_fail_slider.value=0
            report_fail_slider.disabled=False
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=2
            report_fail_value_box.children=[report_score_box]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

            
        else:
            report_poor_checkbox.value=False
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True

            report_score_box.value=0
            report_fail_value_box.children=[report_score_box]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

report_fail_checkbox.observe(report_fail_checkbox_f)

# Behaviour for Fail slider

def report_fail_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            report_score_box.value=1
        elif change['new']==0:
            report_score_box.value=2
        else:
            report_score_box.value=3

report_fail_slider.observe(report_fail_slider_f)


# Behaviour for Poor checkbox

def report_poor_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            report_fail_checkbox.value=True
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=False
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=4
            report_fail_value_box.children=[]
            report_poor_value_box.children=[report_score_box]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

            
        else:
            report_sufficient_checkbox.value=False
            
            report_fail_slider.value=0
            report_fail_slider.disabled=False
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=2
            report_fail_value_box.children=[report_score_box]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

report_poor_checkbox.observe(report_poor_checkbox_f)

# Behaviour for Poor slider

def report_poor_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            report_score_box.value=3
        elif change['new']==0:
            report_score_box.value=4
        else:
            report_score_box.value=5

report_poor_slider.observe(report_poor_slider_f)

# Behaviour for Sufficient checkbox

def report_sufficient_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            report_poor_checkbox.value=True
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=False
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=6
            report_fail_value_box.children=[]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[report_score_box]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]
            
        else:
            report_good_checkbox.value=False
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=False
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=4
            report_fail_value_box.children=[]
            report_poor_value_box.children=[report_score_box]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

report_sufficient_checkbox.observe(report_sufficient_checkbox_f)


# Behaviour for Sufficient slider

def report_sufficient_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            report_score_box.value=5
        elif change['new']==0:
            report_score_box.value=6
        else:
            report_score_box.value=7

report_sufficient_slider.observe(report_sufficient_slider_f)

# Behaviour for Good checkbox

def report_good_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            report_sufficient_checkbox.value=True
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=False
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=8
            report_fail_value_box.children=[]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[report_score_box]
            report_excellent_value_box.children=[]

        else:
            report_excellent_checkbox.value=False
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=False
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=6
            report_fail_value_box.children=[]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[report_score_box]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[]

report_good_checkbox.observe(report_good_checkbox_f)

# Behaviour for Good slider

def report_good_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            report_score_box.value=7
        elif change['new']==0:
            report_score_box.value=8
        else:
            report_score_box.value=9

report_good_slider.observe(report_good_slider_f)

# Behaviour for Good checkbox

def report_excellent_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            report_good_checkbox.value=True
            
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=True
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=False
            
            report_score_box.value=10
            report_fail_value_box.children=[]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[report_score_box]
            
        else:
            report_fail_slider.value=0
            report_fail_slider.disabled=True
            
            report_poor_slider.value=0
            report_poor_slider.disabled=True
            
            report_sufficient_slider.value=0
            report_sufficient_slider.disabled=True
            
            report_good_slider.value=0
            report_good_slider.disabled=False
            
            report_excellent_slider.value=0
            report_excellent_slider.disabled=True
            
            report_score_box.value=8
            report_fail_value_box.children=[]
            report_poor_value_box.children=[]
            report_sufficient_value_box.children=[]
            report_good_value_box.children=[]
            report_excellent_value_box.children=[report_score_box]

report_excellent_checkbox.observe(report_excellent_checkbox_f)

# Behaviour for Excellent slider

def report_excellent_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            report_score_box.value=9
        else:
            report_score_box.value=10

report_excellent_slider.observe(report_excellent_slider_f)

# Now we need to put all the report stuff into a single widget.

report_widget=widgets.VBox([widgets.HTML(value='<h2>Write a report</h2>'),
                           report_fail_row,
                           report_poor_row,
                           report_sufficient_row,
                           report_good_row,
                           report_excellent_row,
                           report_comments_box])

# display(report_widget)

# %% [markdown]
# ## The reflection widgets

# %%
# reflection issues: fail

t='No adequate engagement with this criterion.'

reflection_fail_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

reflection_fail_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

reflection_fail_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

reflection_fail_row=widgets.HBox([widgets.Text(value='Fail',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             reflection_fail_checkbox,
                             reflection_fail_slider,
                             reflection_fail_value_box])

# reflection issues: poor

t='States how all datasets are stored and processed.'

reflection_poor_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

reflection_poor_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

reflection_poor_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

reflection_poor_row=widgets.HBox([widgets.Text(value='Poor',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=True,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             reflection_poor_checkbox,
                             reflection_poor_slider,
                             reflection_poor_value_box])


# reflection issues: Sufficient

t='As above, plus: \nGives some justification for why the \
datasets are stored in this way. Merely lists problems that \
occurred during data acquisition, cleaning and importing. \
Merely lists problems with combining the datasets.'

reflection_sufficient_checkbox=widgets.Checkbox(value=False,
                                           # description='Check me',
                                           disabled=False,
                                           layout=widgets.Layout(width='5%'))

reflection_sufficient_slider=widgets.IntSlider(value=0,
                                          min=-1,
                                          max=1,
                                          step=1,
                                          disabled=True,
                                          continuous_update=False,
                                          orientation='horizontal',
                                          readout=False,
                                          readout_format='d',
                                          layout=widgets.Layout(width='10%'))

reflection_sufficient_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

reflection_sufficient_row=widgets.HBox([widgets.Text(value='Sufficient',
                                          layout=widgets.Layout(width='10%')),
                                   widgets.Textarea(value=t,
                                                    disabled=False,
                                                    layout=widgets.Layout(width='65%',
                                                                          height='100px')),
                                   reflection_sufficient_checkbox,
                                   reflection_sufficient_slider,
                                   reflection_sufficient_value_box])


# reflection issues: Good

t='As above, plus: \nGives full justification for why the dataset \
storage chosen is appropriate, including comparison of viable \
alternatives. States only significant issues in data importing and \
cleaning, and how they were addressed. States only significant \
issues in data combination, and how they were addressed.'


reflection_good_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

reflection_good_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

reflection_good_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

reflection_good_row=widgets.HBox([widgets.Text(value='Good',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             reflection_good_checkbox,
                             reflection_good_slider,
                             reflection_good_value_box])

# reflection issues: Excellent

t='As above, plus: \nClearly links issues of data quality to \
limitations of the analysis.'


reflection_excellent_checkbox=widgets.Checkbox(value=False,
                                          # description='Check me',
                                          disabled=False,
                                          layout=widgets.Layout(width='5%'))

reflection_excellent_slider=widgets.IntSlider(value=0,
                                         min=-1,
                                         max=0,
                                         step=1,
                                         disabled=True,
                                         continuous_update=False,
                                         orientation='horizontal',
                                         readout=False,
                                         readout_format='d',
                                         layout=widgets.Layout(width='10%'))

reflection_excellent_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

reflection_excellent_row=widgets.HBox([widgets.Text(value='Excellent',
                                          layout=widgets.Layout(width='10%')),
                                  widgets.Textarea(value=t,
                                                   disabled=False,
                                                   layout=widgets.Layout(width='65%',
                                                                         height='100px')),
                                  reflection_excellent_checkbox,
                                  reflection_excellent_slider,
                                  reflection_excellent_value_box])

reflection_comments_box=widgets.Textarea(value='',
                                    placeholder="Comments on reflection issues ",
                                    disabled=False,
                                    layout=widgets.Layout(width='70%'))

reflection_score_box=widgets.IntText(value=0,
                                disabled=True,
                                layout=widgets.Layout(width='100%'))

reflection_fail_value_box.children=[reflection_score_box]

# Behaviour for Fail checkbox

def reflection_fail_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=False
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=2
            reflection_fail_value_box.children=[reflection_score_box]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

            
        else:
            reflection_poor_checkbox.value=False
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True

            reflection_score_box.value=0
            reflection_fail_value_box.children=[reflection_score_box]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

reflection_fail_checkbox.observe(reflection_fail_checkbox_f)

# Behaviour for Fail slider

def reflection_fail_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            reflection_score_box.value=1
        elif change['new']==0:
            reflection_score_box.value=2
        else:
            reflection_score_box.value=3

reflection_fail_slider.observe(reflection_fail_slider_f)


# Behaviour for Poor checkbox

def reflection_poor_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            reflection_fail_checkbox.value=True
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=False
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=4
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[reflection_score_box]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

            
        else:
            reflection_sufficient_checkbox.value=False
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=False
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=2
            reflection_fail_value_box.children=[reflection_score_box]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

reflection_poor_checkbox.observe(reflection_poor_checkbox_f)

# Behaviour for Poor slider

def reflection_poor_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            reflection_score_box.value=3
        elif change['new']==0:
            reflection_score_box.value=4
        else:
            reflection_score_box.value=5

reflection_poor_slider.observe(reflection_poor_slider_f)

# Behaviour for Sufficient checkbox

def reflection_sufficient_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            reflection_poor_checkbox.value=True
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=False
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=6
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[reflection_score_box]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]
            
        else:
            reflection_good_checkbox.value=False
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=False
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=4
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[reflection_score_box]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

reflection_sufficient_checkbox.observe(reflection_sufficient_checkbox_f)


# Behaviour for Sufficient slider

def reflection_sufficient_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            reflection_score_box.value=5
        elif change['new']==0:
            reflection_score_box.value=6
        else:
            reflection_score_box.value=7

reflection_sufficient_slider.observe(reflection_sufficient_slider_f)

# Behaviour for Good checkbox

def reflection_good_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            reflection_sufficient_checkbox.value=True
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=False
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=8
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[reflection_score_box]
            reflection_excellent_value_box.children=[]

        else:
            reflection_excellent_checkbox.value=False
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=False
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=6
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[reflection_score_box]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[]

reflection_good_checkbox.observe(reflection_good_checkbox_f)

# Behaviour for Good slider

def reflection_good_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            reflection_score_box.value=7
        elif change['new']==0:
            reflection_score_box.value=8
        else:
            reflection_score_box.value=9

reflection_good_slider.observe(reflection_good_slider_f)

# Behaviour for Good checkbox

def reflection_excellent_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            reflection_good_checkbox.value=True
            
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=True
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=False
            
            reflection_score_box.value=10
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[reflection_score_box]
            
        else:
            reflection_fail_slider.value=0
            reflection_fail_slider.disabled=True
            
            reflection_poor_slider.value=0
            reflection_poor_slider.disabled=True
            
            reflection_sufficient_slider.value=0
            reflection_sufficient_slider.disabled=True
            
            reflection_good_slider.value=0
            reflection_good_slider.disabled=False
            
            reflection_excellent_slider.value=0
            reflection_excellent_slider.disabled=True
            
            reflection_score_box.value=8
            reflection_fail_value_box.children=[]
            reflection_poor_value_box.children=[]
            reflection_sufficient_value_box.children=[]
            reflection_good_value_box.children=[]
            reflection_excellent_value_box.children=[reflection_score_box]

reflection_excellent_checkbox.observe(reflection_excellent_checkbox_f)

# Behaviour for Excellent slider

def reflection_excellent_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            reflection_score_box.value=9
        else:
            reflection_score_box.value=10

reflection_excellent_slider.observe(reflection_excellent_slider_f)

# Now we need to put all the reflection stuff into a single widget.

reflection_widget=widgets.VBox([widgets.HTML(value='<h2>Technical reflection on the data investigation</h2>'),
                           reflection_fail_row,
                           reflection_poor_row,
                           reflection_sufficient_row,
                           reflection_good_row,
                           reflection_excellent_row,
                           reflection_comments_box])

# display(reflection_widget)

# %% [markdown]
# ## Analysis widgets

# %%
# analysis issues: fail

t='No adequate engagement with this criterion.'

analysis_fail_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

analysis_fail_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

analysis_fail_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

analysis_fail_row=widgets.HBox([widgets.Text(value='Fail',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             analysis_fail_checkbox,
                             analysis_fail_slider,
                             analysis_fail_value_box])

# analysis issues: poor

t='Uses either k-NN or k-means to examine a dataset. Relates \
two datasets.\nUses a combination of two datasets to draw \
conclusions that could not be drawn from either set alone.\n\
Presents results in a comprehensible form. Uses analysis \
techniques that produce the answers given in the report. \
Uses analysis techniques that are suitable for the datasets.\n\
Provides all technical resources needed to replicate the findings.'

analysis_poor_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

analysis_poor_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

analysis_poor_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

analysis_poor_row=widgets.HBox([widgets.Text(value='Poor',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=True,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             analysis_poor_checkbox,
                             analysis_poor_slider,
                             analysis_poor_value_box])


# analysis issues: Sufficient

t='As above, plus: \nAnalysis results are presented in \
appropriate forms that illustrate the significant results \
of the analysis. Uses the most appropriate analysis methods \
for generating the desired results. If necessary, \
appropriately modifies the original data to convert it into \
a form for the chosen analysis technique. Considers \
confounding factors that could limit the results.'

analysis_sufficient_checkbox=widgets.Checkbox(value=False,
                                           # description='Check me',
                                           disabled=False,
                                           layout=widgets.Layout(width='5%'))

analysis_sufficient_slider=widgets.IntSlider(value=0,
                                          min=-1,
                                          max=1,
                                          step=1,
                                          disabled=True,
                                          continuous_update=False,
                                          orientation='horizontal',
                                          readout=False,
                                          readout_format='d',
                                          layout=widgets.Layout(width='10%'))

analysis_sufficient_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

analysis_sufficient_row=widgets.HBox([widgets.Text(value='Sufficient',
                                          layout=widgets.Layout(width='10%')),
                                   widgets.Textarea(value=t,
                                                    disabled=False,
                                                    layout=widgets.Layout(width='65%',
                                                                          height='100px')),
                                   analysis_sufficient_checkbox,
                                   analysis_sufficient_slider,
                                   analysis_sufficient_value_box])


# analysis issues: Good

t='As above, plus: \nResults are presented in a form that \
highlights the relevant results. Limitations of the chosen \
methods are stated in the report. If appropriate, \
identifies several relevant confounding factors that could \
limit the results.'


analysis_good_checkbox=widgets.Checkbox(value=False,
                                     # description='Check me',
                                     disabled=False,
                                     layout=widgets.Layout(width='5%'))

analysis_good_slider=widgets.IntSlider(value=0,
                                    min=-1,
                                    max=1,
                                    step=1,
                                    disabled=True,
                                    continuous_update=False,
                                    orientation='horizontal',
                                    readout=False,
                                    readout_format='d',
                                    layout=widgets.Layout(width='10%'))

analysis_good_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

analysis_good_row=widgets.HBox([widgets.Text(value='Good',
                                          layout=widgets.Layout(width='10%')),
                             widgets.Textarea(value=t,
                                              disabled=False,
                                              layout=widgets.Layout(width='65%',
                                                                    height='100px')),
                             analysis_good_checkbox,
                             analysis_good_slider,
                             analysis_good_value_box])

# analysis issues: Excellent

t='As above, plus: \nLimitations of the chosen methods \
clearly link to limits to the validity of the conclusions \
that can be drawn from the results. States the scale of \
impact of confounding factors.'


analysis_excellent_checkbox=widgets.Checkbox(value=False,
                                          # description='Check me',
                                          disabled=False,
                                          layout=widgets.Layout(width='5%'))

analysis_excellent_slider=widgets.IntSlider(value=0,
                                         min=-1,
                                         max=0,
                                         step=1,
                                         disabled=True,
                                         continuous_update=False,
                                         orientation='horizontal',
                                         readout=False,
                                         readout_format='d',
                                         layout=widgets.Layout(width='10%'))

analysis_excellent_value_box=widgets.Box(layout=widgets.Layout(width='10%'))

analysis_excellent_row=widgets.HBox([widgets.Text(value='Excellent',
                                          layout=widgets.Layout(width='10%')),
                                  widgets.Textarea(value=t,
                                                   disabled=False,
                                                   layout=widgets.Layout(width='65%',
                                                                         height='100px')),
                                  analysis_excellent_checkbox,
                                  analysis_excellent_slider,
                                  analysis_excellent_value_box])

analysis_comments_box=widgets.Textarea(value='',
                                    placeholder="Comments on analysis issues ",
                                    disabled=False,
                                    layout=widgets.Layout(width='70%'))

analysis_score_box=widgets.IntText(value=0,
                                disabled=True,
                                layout=widgets.Layout(width='100%'))

analysis_fail_value_box.children=[analysis_score_box]

# Behaviour for Fail checkbox

def analysis_fail_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=False
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=2
            analysis_fail_value_box.children=[analysis_score_box]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

            
        else:
            analysis_poor_checkbox.value=False
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True

            analysis_score_box.value=0
            analysis_fail_value_box.children=[analysis_score_box]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

analysis_fail_checkbox.observe(analysis_fail_checkbox_f)

# Behaviour for Fail slider

def analysis_fail_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            analysis_score_box.value=1
        elif change['new']==0:
            analysis_score_box.value=2
        else:
            analysis_score_box.value=3

analysis_fail_slider.observe(analysis_fail_slider_f)


# Behaviour for Poor checkbox

def analysis_poor_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            analysis_fail_checkbox.value=True
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=False
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=4
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[analysis_score_box]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

            
        else:
            analysis_sufficient_checkbox.value=False
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=False
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=2
            analysis_fail_value_box.children=[analysis_score_box]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

analysis_poor_checkbox.observe(analysis_poor_checkbox_f)

# Behaviour for Poor slider

def analysis_poor_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            analysis_score_box.value=3
        elif change['new']==0:
            analysis_score_box.value=4
        else:
            analysis_score_box.value=5

analysis_poor_slider.observe(analysis_poor_slider_f)

# Behaviour for Sufficient checkbox

def analysis_sufficient_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            analysis_poor_checkbox.value=True
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=False
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=6
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[analysis_score_box]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]
            
        else:
            analysis_good_checkbox.value=False
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=False
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=4
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[analysis_score_box]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

analysis_sufficient_checkbox.observe(analysis_sufficient_checkbox_f)


# Behaviour for Sufficient slider

def analysis_sufficient_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            analysis_score_box.value=5
        elif change['new']==0:
            analysis_score_box.value=6
        else:
            analysis_score_box.value=7

analysis_sufficient_slider.observe(analysis_sufficient_slider_f)

# Behaviour for Good checkbox

def analysis_good_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            analysis_sufficient_checkbox.value=True
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=False
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=8
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[analysis_score_box]
            analysis_excellent_value_box.children=[]

        else:
            analysis_excellent_checkbox.value=False
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=False
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=6
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[analysis_score_box]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[]

analysis_good_checkbox.observe(analysis_good_checkbox_f)

# Behaviour for Good slider

def analysis_good_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            analysis_score_box.value=7
        elif change['new']==0:
            analysis_score_box.value=8
        else:
            analysis_score_box.value=9

analysis_good_slider.observe(analysis_good_slider_f)

# Behaviour for Good checkbox

def analysis_excellent_checkbox_f(change):
    if change['name']=='value':
        if change['new']==True:
            
            analysis_good_checkbox.value=True
            
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=True
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=False
            
            analysis_score_box.value=10
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[analysis_score_box]
            
        else:
            analysis_fail_slider.value=0
            analysis_fail_slider.disabled=True
            
            analysis_poor_slider.value=0
            analysis_poor_slider.disabled=True
            
            analysis_sufficient_slider.value=0
            analysis_sufficient_slider.disabled=True
            
            analysis_good_slider.value=0
            analysis_good_slider.disabled=False
            
            analysis_excellent_slider.value=0
            analysis_excellent_slider.disabled=True
            
            analysis_score_box.value=8
            analysis_fail_value_box.children=[]
            analysis_poor_value_box.children=[]
            analysis_sufficient_value_box.children=[]
            analysis_good_value_box.children=[]
            analysis_excellent_value_box.children=[analysis_score_box]

analysis_excellent_checkbox.observe(analysis_excellent_checkbox_f)

# Behaviour for Excellent slider

def analysis_excellent_slider_f(change):
    if change['name']=='value':
        if change['new']==-1:
            analysis_score_box.value=9
        else:
            analysis_score_box.value=10

analysis_excellent_slider.observe(analysis_excellent_slider_f)

# Now we need to put all the analysis stuff into a single widget.

analysis_widget=widgets.VBox([widgets.HTML(value='<h2>Apply appropriate analysis techniques</h2>'),
                           analysis_fail_row,
                           analysis_poor_row,
                           analysis_sufficient_row,
                           analysis_good_row,
                           analysis_excellent_row,
                           analysis_comments_box])

# display(analysis_widget)

# %% [markdown]
# ## Putting it together

# %%
# Work out the score for each criterion

legal_score_final=widgets.IntText(value=legal_score_box.value,
                                  disabled=True,
                                  layout=widgets.Layout(width='100%'))
def legal_score_box_f(change):
    legal_score_final.value=legal_score_box.value
legal_score_box.observe(legal_score_box_f)

data_score_final=widgets.IntText(value=data_score_box.value,
                                 disabled=True,
                                 layout=widgets.Layout(width='100%'))
def data_score_box_f(change):
    data_score_final.value=data_score_box.value                                
data_score_box.observe(data_score_box_f)

report_score_final=widgets.IntText(value=report_score_box.value,
                                   disabled=True,
                                   layout=widgets.Layout(width='100%'))
def report_score_box_f(change):
    report_score_final.value=report_score_box.value*2
report_score_box.observe(report_score_box_f)

reflection_score_final=widgets.IntText(value=reflection_score_box.value,
                                       disabled=True,
                                       layout=widgets.Layout(width='100%'))
def reflection_score_box_f(change):
    reflection_score_final.value=reflection_score_box.value                                
reflection_score_box.observe(reflection_score_box_f)

analysis_score_final=widgets.IntText(value=analysis_score_box.value,
                                     disabled=True,
                                     layout=widgets.Layout(width='100%'))
def analysis_score_box_f(change):
    analysis_score_final.value=analysis_score_box.value*3                             
analysis_score_box.observe(analysis_score_box_f)

# %%
grand_total_score=widgets.IntText(value=sum([legal_score_final.value,
                                             data_score_final.value,
                                             report_score_final.value,
                                             reflection_score_final.value,
                                             analysis_score_final.value]),
                                  disabled=True,
                                  layout=widgets.Layout(width='100%'))

# %%
# Update the values when user changes the checkboxes/sliders

def legal_score_final_f(change):
    grand_total_score.value=sum([legal_score_final.value,
                                 data_score_final.value,
                                 report_score_final.value,
                                 reflection_score_final.value,
                                 analysis_score_final.value])
legal_score_final.observe(legal_score_final_f)

def data_score_final_f(change):
    grand_total_score.value=sum([legal_score_final.value,
                                 data_score_final.value,
                                 report_score_final.value,
                                 reflection_score_final.value,
                                 analysis_score_final.value])
data_score_final.observe(data_score_final_f)

def report_score_final_f(change):
    grand_total_score.value=sum([legal_score_final.value,
                                 data_score_final.value,
                                 report_score_final.value,
                                 reflection_score_final.value,
                                 analysis_score_final.value])
report_score_final.observe(report_score_final_f)

def reflection_score_final_f(change):
    grand_total_score.value=sum([legal_score_final.value,
                                 data_score_final.value,
                                 report_score_final.value,
                                 reflection_score_final.value,
                                 analysis_score_final.value])
reflection_score_final.observe(reflection_score_final_f)

def analysis_score_final_f(change):
    grand_total_score.value=sum([legal_score_final.value,
                                 data_score_final.value,
                                 report_score_final.value,
                                 reflection_score_final.value,
                                 analysis_score_final.value])
analysis_score_final.observe(analysis_score_final_f)

# %%
# Generate text to cut+paste into Oscar

def generate_oscar_text():
    
    # Get legal class
    if legal_excellent_checkbox.value:
        legal_class='E'
        if legal_excellent_slider.value==-1:
            legal_class+='-'
        if legal_excellent_slider.value==1:
            legal_class+='+'
    elif legal_good_checkbox.value:
        legal_class='G'
        if legal_good_slider.value==-1:
            legal_class+='-'
        if legal_good_slider.value==1:
            legal_class+='+'
    elif legal_sufficient_checkbox.value:
        legal_class='S'
        if legal_sufficient_slider.value==-1:
            legal_class+='-'
        if legal_sufficient_slider.value==1:
            legal_class+='+'
    elif legal_poor_checkbox.value:
        legal_class='P'
        if legal_poor_slider.value==-1:
            legal_class+='-'
        if legal_poor_slider.value==1:
            legal_class+='+'
    elif legal_fail_checkbox.value:
        legal_class='F'
        if legal_fail_slider.value==-1:
            legal_class+='-'
        if legal_fail_slider.value==1:
            legal_class+='+'
    else:
        legal_class=''

    # Get data class
    if data_excellent_checkbox.value:
        data_class='E'
        if data_excellent_slider.value==-1:
            data_class+='-'
        if data_excellent_slider.value==1:
            data_class+='+'
    elif data_good_checkbox.value:
        data_class='G'
        if data_good_slider.value==-1:
            data_class+='-'
        if data_good_slider.value==1:
            data_class+='+'
    elif data_sufficient_checkbox.value:
        data_class='S'
        if data_sufficient_slider.value==-1:
            data_class+='-'
        if data_sufficient_slider.value==1:
            data_class+='+'
    elif data_poor_checkbox.value:
        data_class='P'
        if data_poor_slider.value==-1:
            data_class+='-'
        if data_poor_slider.value==1:
            data_class+='+'
    elif data_fail_checkbox.value:
        data_class='F'
        if data_fail_slider.value==-1:
            data_class+='-'
        if data_fail_slider.value==1:
            data_class+='+'
    else:
        data_class=''

    # Get report class
    if report_excellent_checkbox.value:
        report_class='E'
        if report_excellent_slider.value==-1:
            report_class+='-'
        if report_excellent_slider.value==1:
            report_class+='+'
    elif report_good_checkbox.value:
        report_class='G'
        if report_good_slider.value==-1:
            report_class+='-'
        if report_good_slider.value==1:
            report_class+='+'
    elif report_sufficient_checkbox.value:
        report_class='S'
        if report_sufficient_slider.value==-1:
            report_class+='-'
        if report_sufficient_slider.value==1:
            report_class+='+'
    elif report_poor_checkbox.value:
        report_class='P'
        if report_poor_slider.value==-1:
            report_class+='-'
        if report_poor_slider.value==1:
            report_class+='+'
    elif report_fail_checkbox.value:
        report_class='F'
        if report_fail_slider.value==-1:
            report_class+='-'
        if report_fail_slider.value==1:
            report_class+='+'
    else:
        report_class=''


    # Get reflection class
    if reflection_excellent_checkbox.value:
        reflection_class='E'
        if reflection_excellent_slider.value==-1:
            reflection_class+='-'
        if reflection_excellent_slider.value==1:
            reflection_class+='+'
    elif reflection_good_checkbox.value:
        reflection_class='G'
        if reflection_good_slider.value==-1:
            reflection_class+='-'
        if reflection_good_slider.value==1:
            reflection_class+='+'
    elif reflection_sufficient_checkbox.value:
        reflection_class='S'
        if reflection_sufficient_slider.value==-1:
            reflection_class+='-'
        if reflection_sufficient_slider.value==1:
            reflection_class+='+'
    elif reflection_poor_checkbox.value:
        reflection_class='P'
        if reflection_poor_slider.value==-1:
            reflection_class+='-'
        if reflection_poor_slider.value==1:
            reflection_class+='+'
    elif reflection_fail_checkbox.value:
        reflection_class='F'
        if reflection_fail_slider.value==-1:
            reflection_class+='-'
        if reflection_fail_slider.value==1:
            reflection_class+='+'
    else:
        reflection_class=''

    # Get analysis class
    if analysis_excellent_checkbox.value:
        analysis_class='E'
        if analysis_excellent_slider.value==-1:
            analysis_class+='-'
        if analysis_excellent_slider.value==1:
            analysis_class+='+'
    elif analysis_good_checkbox.value:
        analysis_class='G'
        if analysis_good_slider.value==-1:
            analysis_class+='-'
        if analysis_good_slider.value==1:
            analysis_class+='+'
    elif analysis_sufficient_checkbox.value:
        analysis_class='S'
        if analysis_sufficient_slider.value==-1:
            analysis_class+='-'
        if analysis_sufficient_slider.value==1:
            analysis_class+='+'
    elif analysis_poor_checkbox.value:
        analysis_class='P'
        if analysis_poor_slider.value==-1:
            analysis_class+='-'
        if analysis_poor_slider.value==1:
            analysis_class+='+'
    elif analysis_fail_checkbox.value:
        analysis_class='F'
        if analysis_fail_slider.value==-1:
            analysis_class+='-'
        if analysis_fail_slider.value==1:
            analysis_class+='+'
    else:
        analysis_class=''



        
        
        
    return '''Legal mark: \t{}\t\t{}
Legal comments: {}

Data mark: \t{}\t\t{}
Data comments: {}

Report mark: \t{}\t\t{}
Report comments: {}

Reflection mark: \t{}\t\t{}
Reflection comments: {}

Analysis mark: \t{}\t\t{}
Analysis comments: {}'''.format(legal_class,
                                legal_score_box.value, 
                                legal_comments_box.value,
                                data_class,
                                data_score_box.value,
                                data_comments_box.value,
                                report_class,
                                report_score_box.value,
                                report_comments_box.value,
                                reflection_class,
                                reflection_score_box.value,
                                reflection_comments_box.value,
                                analysis_class,
                                analysis_score_box.value,
                                analysis_comments_box.value)

# %%
# Comments for Oscar

oscar_comments=widgets.Textarea(generate_oscar_text(),
                                layout=widgets.Layout(width='90%',
                                                      height='400px'),
                                disabled=True)

# And link the comments boxes to the Oscar text.

def comment_updates_oscar_text(change):
    oscar_comments.value=generate_oscar_text()

legal_comments_box.observe(comment_updates_oscar_text)
data_comments_box.observe(comment_updates_oscar_text)
report_comments_box.observe(comment_updates_oscar_text)
reflection_comments_box.observe(comment_updates_oscar_text)
analysis_comments_box.observe(comment_updates_oscar_text)

# %%
# Calculate final score

final_grade=widgets.Text(value='Fail',
                         disabled=True,
                         layout=widgets.Layout(width='100%'))

def grand_total_score_f(change):
    if grand_total_score.value<=31:
        final_grade.value='Fail'
    elif grand_total_score.value<=43:
        final_grade.value='Pass 4'
    elif grand_total_score.value<=55:
        final_grade.value='Pass 3'
    elif grand_total_score.value<=67:
        final_grade.value='Pass 2'
    else:
        final_grade.value='Pass 1'
    
    oscar_comments.value=generate_oscar_text()

grand_total_score.observe(grand_total_score_f)

# %%
# Create a widget for the final marks

thresholds_widget=widgets.HBox([widgets.VBox([widgets.Label(s) for s in ['Total Mark',
                                                                         '0-31',
                                                                         '32-43',
                                                                         '44-55',
                                                                         '56-67',
                                                                         '68-80']]),
                                widgets.VBox([widgets.Label(s) for s in ['Final Grade',
                                                                         'Fail',
                                                                         'Pass 4',
                                                                         'Pass 3',
                                                                         'Pass 2',
                                                                         'Pass 1']])],
                               layout=widgets.Layout(width='100%'))

grade_calculation=widgets.HBox([widgets.VBox([widgets.Label('Legal issues: ',
                                                            layout=widgets.Layout(width='100%')),
                                              widgets.Label('Use of data: ',
                                                            layout=widgets.Layout(width='100%')),
                                              widgets.Label('Write a report: ',
                                                            layout=widgets.Layout(width='100%')),
                                              widgets.Label('Technical reflections: ',
                                                            layout=widgets.Layout(width='100%')),
                                              widgets.Label('Analysis techniques: ',
                                                            layout=widgets.Layout(width='100%'))],
                                             layout=widgets.Layout(width='15%')),
                                widgets.VBox([legal_score_box,
                                              data_score_box,
                                              report_score_box,
                                              reflection_score_box,
                                              analysis_score_box],
                                             layout=widgets.Layout(width='5%')),
                                widgets.VBox([widgets.Label('x 1'),
                                              widgets.Label('x 1'),
                                              widgets.Label('x 2'),
                                              widgets.Label('x 1'),
                                              widgets.Label('x 3'),
                                              widgets.Label('Total'),
                                              widgets.Label('Grade')],
                                             layout=widgets.Layout(width='5%')),
                                widgets.VBox([legal_score_final,
                                              data_score_final,
                                              report_score_final,
                                              reflection_score_final,
                                              analysis_score_final,
                                              grand_total_score,
                                              final_grade],
                                             layout=widgets.Layout(width='10%')),
                                widgets.VBox(layout=widgets.Layout(width='20%')),
                                widgets.VBox([thresholds_widget],
                                             layout=widgets.Layout(width='35%'))])



final_grade_table=widgets.VBox([widgets.HTML(value='<h2>Final marks</h2>'),
                                grade_calculation])

# %%
complete_mark_dashboard=widgets.VBox([legal_widget,
                                      data_widget,
                                      report_widget,
                                      reflection_widget,
                                      analysis_widget,
                                      final_grade_table,
                                      widgets.Box(layout=widgets.Layout(height='60px')),
                                      oscar_comments])

# %%
display(complete_mark_dashboard)
